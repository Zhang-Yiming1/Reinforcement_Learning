# %%
import collections
import random
import gym,os
import  numpy as np
import  tensorflow as tf
from    tensorflow import keras
from    tensorflow.keras import layers,optimizers,losses

# %%
env = gym.make("CartPole-v1") # 创建游戏环境

# %%
observation = env.reset() # 游戏初始化
action = env.action_space.sample() # 随机生成一个动作
# 与环境交互，返回新的状态，奖励，是否结束标志，其他信息
observation, reward, done, info = env.step(action)
if done:#游戏回合结束，复位状态
    observation = env.reset()
env.close()

# %%
class Qnet(keras.Model):
    def __init__(self):
        # 创建Q网络，输入为状态向量，输出为动作的Q值
        super(Qnet, self).__init__()
        self.fc1 = layers.Dense(256, kernel_initializer='he_normal')
        self.fc2 = layers.Dense(256, kernel_initializer='he_normal')
        self.fc3 = layers.Dense(2, kernel_initializer='he_normal')

    def call(self, x, training=None):
        x = tf.nn.relu(self.fc1(x))
        x = tf.nn.relu(self.fc2(x))
        x = self.fc3(x)
        return x

    def sample_action(self, s, epsilon):
        s = tf.constant(s, dtype=tf.float32)
        s = tf.expand_dims(s, axis=0)
        out = self(s)[0]
        coin = random.random()
        # 策略改进：e-贪心方式
        if coin < epsilon:
            return random.randint(0, 1)
        else:  
            return int(tf.argmax(out))

# %%
class ReplayBuffer():
    # 经验回放池
    def __init__(self):
        # 双向队列
        self.buffer = collections.deque(maxlen=buffer_limit)

    def put(self, transition):
        self.buffer.append(transition)

    def sample(self, n):
        # 从回放池采样
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []
        # 按类别进行整理
        for transition in mini_batch:
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])
        # 转换成Tensor
        return tf.constant(s_lst, dtype=tf.float32),\
                      tf.constant(a_lst, dtype=tf.int32), \
                      tf.constant(r_lst, dtype=tf.float32), \
                      tf.constant(s_prime_lst, dtype=tf.float32), \
                      tf.constant(done_mask_lst, dtype=tf.float32)


    def size(self):
        return len(self.buffer)

# %%
def train(q, q_target, memory, optimizer):
    # 通过Q网络和target网络来构造贝尔曼方程的误差，
    # 并只更新Q网络，target网络的更新会滞后Q网络
    huber = losses.Huber()
    for i in range(10):  
        # 从缓冲池采样
        s, a, r, s_prime, done_mask = memory.sample(batch_size)
        with tf.GradientTape() as tape:
            q_out = q(s)  # 得到Q(s,a)的分布
            indices = tf.expand_dims(tf.range(a.shape[0]), axis=1)
            indices = tf.concat([indices, a], axis=1)
            q_a = tf.gather_nd(q_out, indices) # 动作的概率值
            q_a = tf.expand_dims(q_a, axis=1) 
            # 得到Q(s',a)的最大值，它来自target网络！ 
            max_q_prime = tf.reduce_max(q_target(s_prime),axis=1,keepdims=True)
            # 构造Q(s,a_t)的目标值，来自贝尔曼方程
            target = r + gamma * max_q_prime * done_mask
            # 计算Q(s,a_t)与目标值的误差
            loss = huber(q_a, target)
        # 更新网络，使得Q(s,a_t)估计符合贝尔曼方程
        grads = tape.gradient(loss, q.trainable_variables)
        optimizer.apply_gradients(zip(grads, q.trainable_variables))

# %%
# Hyperparameters
learning_rate = 0.0002
gamma = 0.99
buffer_limit = 50000
batch_size = 32

# %%
def main():
    env = gym.make('CartPole-v1')  # 创建环境
    q = Qnet()  # 创建Q网络
    q_target = Qnet()  # 创建target网络
    q.build(input_shape=(2,4))
    q_target.build(input_shape=(2,4))
    for src, dest in zip(q.variables, q_target.variables):
        dest.assign(src) 
    memory = ReplayBuffer()  # 创建回放池

    print_interval = 20
    score = 0.0
    optimizer = optimizers.Adam(lr=learning_rate)

    for n_epi in range(10000):  # 训练次数
        # epsilon概率也会8%到1%衰减，越到后面越使用Q值最大的动作
        epsilon = max(0.01, 0.08 - 0.01 * (n_epi / 200))
        s = env.reset()  # 复位环境
        for t in range(600):  # 一个回合最大时间戳
            # 根据当前Q网络提取策略，并改进策略
            a = q.sample_action(s, epsilon)
            # 使用改进的策略与环境交互
            s_prime, r, done, info = env.step(a)
            done_mask = 0.0 if done else 1.0  # 结束标志掩码
            memory.put((s, a, r, s_prime, done_mask))
            s = s_prime  # 刷新状态
            score += r  # 记录游戏得分
            if done:  # 回合结束
                break

        if memory.size() > 2000:  # 缓冲池大于2000就可以训练
            train(q, q_target, memory, optimizer)

        if n_epi % print_interval == 0 and n_epi != 0:
            for src, dest in zip(q.variables, q_target.variables):
                dest.assign(src)  # target网络权值更新
            print("# of episode :{}, avg score : {:.1f}, buffer size : {}, " \
                  "epsilon : {:.1f}%" \
                  .format(n_epi, score / print_interval, memory.size(), epsilon * 100))
            score = 0.0
    env.close()

# %%
main()
# Out:
# # of episode :20, avg score : 17.5, buffer size : 350, epsilon : 7.9%
# # of episode :40, avg score : 14.9, buffer size : 648, epsilon : 7.8%
# # of episode :60, avg score : 15.3, buffer size : 954, epsilon : 7.7%
# # of episode :80, avg score : 10.7, buffer size : 1167, epsilon : 7.6%
# # of episode :100, avg score : 13.6, buffer size : 1439, epsilon : 7.5%
# # of episode :120, avg score : 15.0, buffer size : 1739, epsilon : 7.4%
# # of episode :140, avg score : 10.9, buffer size : 1957, epsilon : 7.3%
# # of episode :160, avg score : 10.9, buffer size : 2175, epsilon : 7.2%
# # of episode :180, avg score : 9.9, buffer size : 2374, epsilon : 7.1%
# # of episode :200, avg score : 9.3, buffer size : 2561, epsilon : 7.0%
# # of episode :220, avg score : 9.6, buffer size : 2753, epsilon : 6.9%
# # of episode :240, avg score : 9.6, buffer size : 2944, epsilon : 6.8%
# # of episode :260, avg score : 16.2, buffer size : 3268, epsilon : 6.7%
# # of episode :280, avg score : 20.1, buffer size : 3669, epsilon : 6.6%
# # of episode :300, avg score : 18.1, buffer size : 4031, epsilon : 6.5%
# # of episode :320, avg score : 34.5, buffer size : 4721, epsilon : 6.4%
# # of episode :340, avg score : 29.4, buffer size : 5310, epsilon : 6.3%
# # of episode :360, avg score : 76.9, buffer size : 6848, epsilon : 6.2%
# # of episode :380, avg score : 84.8, buffer size : 8545, epsilon : 6.1%
# # of episode :400, avg score : 97.4, buffer size : 10493, epsilon : 6.0%
# # of episode :420, avg score : 98.0, buffer size : 12452, epsilon : 5.9%
# # of episode :440, avg score : 93.0, buffer size : 14311, epsilon : 5.8%
# # of episode :460, avg score : 102.3, buffer size : 16358, epsilon : 5.7%
# # of episode :480, avg score : 93.0, buffer size : 18219, epsilon : 5.6%
# # of episode :1320, avg score : 136.9, buffer size : 50000, epsilon : 1.4%
# # of episode :1340, avg score : 115.0, buffer size : 50000, epsilon : 1.3%
# # of episode :1360, avg score : 91.5, buffer size : 50000, epsilon : 1.2%
# # of episode :1380, avg score : 45.9, buffer size : 50000, epsilon : 1.1%
# # of episode :1400, avg score : 40.0, buffer size : 50000, epsilon : 1.0%
# # of episode :1420, avg score : 49.2, buffer size : 50000, epsilon : 1.0%
# # of episode :1440, avg score : 41.6, buffer size : 50000, epsilon : 1.0%
# # of episode :1460, avg score : 52.9, buffer size : 50000, epsilon : 1.0%
# # of episode :1480, avg score : 30.8, buffer size : 50000, epsilon : 1.0%
# # of episode :1500, avg score : 59.5, buffer size : 50000, epsilon : 1.0%
# # of episode :1520, avg score : 39.9, buffer size : 50000, epsilon : 1.0%
# # of episode :1540, avg score : 63.2, buffer size : 50000, epsilon : 1.0%
# # of episode :1560, avg score : 41.5, buffer size : 50000, epsilon : 1.0%
# # of episode :1580, avg score : 55.8, buffer size : 50000, epsilon : 1.0%
# # of episode :1600, avg score : 90.2, buffer size : 50000, epsilon : 1.0%
# # of episode :1620, avg score : 98.8, buffer size : 50000, epsilon : 1.0%
# # of episode :1640, avg score : 90.2, buffer size : 50000, epsilon : 1.0%
# # of episode :1660, avg score : 93.3, buffer size : 50000, epsilon : 1.0%
# # of episode :1680, avg score : 51.9, buffer size : 50000, epsilon : 1.0%
# # of episode :1700, avg score : 53.2, buffer size : 50000, epsilon : 1.0%
# # of episode :1720, avg score : 33.4, buffer size : 50000, epsilon : 1.0%
# # of episode :1740, avg score : 57.8, buffer size : 50000, epsilon : 1.0%
# # of episode :1760, avg score : 64.0, buffer size : 50000, epsilon : 1.0%
# # of episode :1780, avg score : 92.2, buffer size : 50000, epsilon : 1.0%
# # of episode :1800, avg score : 47.9, buffer size : 50000, epsilon : 1.0%
# # of episode :1820, avg score : 39.5, buffer size : 50000, epsilon : 1.0%
# # of episode :1840, avg score : 77.3, buffer size : 50000, epsilon : 1.0%
# # of episode :1860, avg score : 68.8, buffer size : 50000, epsilon : 1.0%
# # of episode :1880, avg score : 79.4, buffer size : 50000, epsilon : 1.0%
# # of episode :1900, avg score : 96.2, buffer size : 50000, epsilon : 1.0%
# # of episode :1920, avg score : 93.7, buffer size : 50000, epsilon : 1.0%
# # of episode :1940, avg score : 55.8, buffer size : 50000, epsilon : 1.0%
# # of episode :1960, avg score : 72.6, buffer size : 50000, epsilon : 1.0%
# # of episode :1980, avg score : 71.0, buffer size : 50000, epsilon : 1.0%
# # of episode :2000, avg score : 69.5, buffer size : 50000, epsilon : 1.0%
# # of episode :2020, avg score : 81.1, buffer size : 50000, epsilon : 1.0%
# # of episode :2040, avg score : 68.8, buffer size : 50000, epsilon : 1.0%
# # of episode :2060, avg score : 62.0, buffer size : 50000, epsilon : 1.0%
# # of episode :2080, avg score : 87.0, buffer size : 50000, epsilon : 1.0%
# # of episode :2100, avg score : 77.5, buffer size : 50000, epsilon : 1.0%
# # of episode :4680, avg score : 140.4, buffer size : 50000, epsilon : 1.0%
# # of episode :4700, avg score : 98.7, buffer size : 50000, epsilon : 1.0%
# # of episode :4720, avg score : 101.5, buffer size : 50000, epsilon : 1.0%
# # of episode :4740, avg score : 132.2, buffer size : 50000, epsilon : 1.0%
# # of episode :4760, avg score : 149.8, buffer size : 50000, epsilon : 1.0%
# # of episode :4780, avg score : 274.2, buffer size : 50000, epsilon : 1.0%
# # of episode :4800, avg score : 182.1, buffer size : 50000, epsilon : 1.0%
# # of episode :4820, avg score : 270.8, buffer size : 50000, epsilon : 1.0%
# # of episode :4840, avg score : 196.3, buffer size : 50000, epsilon : 1.0%
# # of episode :4860, avg score : 148.1, buffer size : 50000, epsilon : 1.0%
# # of episode :4880, avg score : 244.1, buffer size : 50000, epsilon : 1.0%
# # of episode :4900, avg score : 112.5, buffer size : 50000, epsilon : 1.0%
# # of episode :4920, avg score : 196.6, buffer size : 50000, epsilon : 1.0%
# # of episode :4940, avg score : 154.9, buffer size : 50000, epsilon : 1.0%
# # of episode :4960, avg score : 275.8, buffer size : 50000, epsilon : 1.0%
# # of episode :4980, avg score : 218.3, buffer size : 50000, epsilon : 1.0%
# # of episode :5000, avg score : 194.4, buffer size : 50000, epsilon : 1.0%
# # of episode :5020, avg score : 191.9, buffer size : 50000, epsilon : 1.0%
# # of episode :5040, avg score : 132.1, buffer size : 50000, epsilon : 1.0%
# # of episode :5060, avg score : 239.8, buffer size : 50000, epsilon : 1.0%
# # of episode :5080, avg score : 136.5, buffer size : 50000, epsilon : 1.0%
# # of episode :5100, avg score : 251.1, buffer size : 50000, epsilon : 1.0%
# # of episode :5120, avg score : 410.5, buffer size : 50000, epsilon : 1.0%
# # of episode :5140, avg score : 264.0, buffer size : 50000, epsilon : 1.0%
# # of episode :5160, avg score : 189.3, buffer size : 50000, epsilon : 1.0%
# # of episode :5180, avg score : 146.7, buffer size : 50000, epsilon : 1.0%
# # of episode :5200, avg score : 161.6, buffer size : 50000, epsilon : 1.0%
# # of episode :5220, avg score : 116.3, buffer size : 50000, epsilon : 1.0%
# # of episode :5240, avg score : 118.2, buffer size : 50000, epsilon : 1.0%
# # of episode :5260, avg score : 93.2, buffer size : 50000, epsilon : 1.0%
# # of episode :5280, avg score : 52.2, buffer size : 50000, epsilon : 1.0%
# # of episode :5300, avg score : 67.7, buffer size : 50000, epsilon : 1.0%
# # of episode :5320, avg score : 102.7, buffer size : 50000, epsilon : 1.0%
# # of episode :5340, avg score : 129.7, buffer size : 50000, epsilon : 1.0%
# # of episode :5360, avg score : 71.4, buffer size : 50000, epsilon : 1.0%
# # of episode :5380, avg score : 85.0, buffer size : 50000, epsilon : 1.0%
# # of episode :5400, avg score : 75.8, buffer size : 50000, epsilon : 1.0%
# # of episode :5420, avg score : 57.9, buffer size : 50000, epsilon : 1.0%
# # of episode :5440, avg score : 59.9, buffer size : 50000, epsilon : 1.0%
# # of episode :5460, avg score : 107.3, buffer size : 50000, epsilon : 1.0%
# # of episode :5480, avg score : 77.6, buffer size : 50000, epsilon : 1.0%
# # of episode :5500, avg score : 60.6, buffer size : 50000, epsilon : 1.0%
# # of episode :5520, avg score : 59.5, buffer size : 50000, epsilon : 1.0%
# # of episode :5540, avg score : 54.1, buffer size : 50000, epsilon : 1.0%
# # of episode :5560, avg score : 84.8, buffer size : 50000, epsilon : 1.0%
# # of episode :5580, avg score : 63.0, buffer size : 50000, epsilon : 1.0%
# # of episode :5600, avg score : 34.2, buffer size : 50000, epsilon : 1.0%
# # of episode :5620, avg score : 49.5, buffer size : 50000, epsilon : 1.0%
# # of episode :5640, avg score : 44.5, buffer size : 50000, epsilon : 1.0%
# # of episode :5660, avg score : 102.8, buffer size : 50000, epsilon : 1.0%
# # of episode :5680, avg score : 44.0, buffer size : 50000, epsilon : 1.0%
# # of episode :5700, avg score : 74.7, buffer size : 50000, epsilon : 1.0%
# # of episode :5720, avg score : 35.9, buffer size : 50000, epsilon : 1.0%
# # of episode :5740, avg score : 56.3, buffer size : 50000, epsilon : 1.0%
# # of episode :5760, avg score : 69.5, buffer size : 50000, epsilon : 1.0%
# # of episode :5780, avg score : 121.7, buffer size : 50000, epsilon : 1.0%
# # of episode :5800, avg score : 66.8, buffer size : 50000, epsilon : 1.0%
# # of episode :5820, avg score : 62.0, buffer size : 50000, epsilon : 1.0%
# # of episode :5840, avg score : 67.4, buffer size : 50000, epsilon : 1.0%
# # of episode :5860, avg score : 33.6, buffer size : 50000, epsilon : 1.0%
# # of episode :5880, avg score : 45.5, buffer size : 50000, epsilon : 1.0%
# # of episode :5900, avg score : 34.0, buffer size : 50000, epsilon : 1.0%
# # of episode :5920, avg score : 61.7, buffer size : 50000, epsilon : 1.0%
# # of episode :5940, avg score : 59.2, buffer size : 50000, epsilon : 1.0%
# # of episode :5960, avg score : 82.5, buffer size : 50000, epsilon : 1.0%
# # of episode :5980, avg score : 71.3, buffer size : 50000, epsilon : 1.0%
# # of episode :6000, avg score : 96.5, buffer size : 50000, epsilon : 1.0%
# # of episode :6020, avg score : 85.2, buffer size : 50000, epsilon : 1.0%
# # of episode :6040, avg score : 94.2, buffer size : 50000, epsilon : 1.0%
# # of episode :6060, avg score : 86.0, buffer size : 50000, epsilon : 1.0%
# # of episode :6080, avg score : 99.8, buffer size : 50000, epsilon : 1.0%
# # of episode :6100, avg score : 89.9, buffer size : 50000, epsilon : 1.0%
# # of episode :6120, avg score : 85.2, buffer size : 50000, epsilon : 1.0%
# # of episode :6140, avg score : 82.2, buffer size : 50000, epsilon : 1.0%
# # of episode :6160, avg score : 89.3, buffer size : 50000, epsilon : 1.0%
# # of episode :6180, avg score : 95.0, buffer size : 50000, epsilon : 1.0%
# # of episode :6200, avg score : 94.5, buffer size : 50000, epsilon : 1.0%
# # of episode :6220, avg score : 97.9, buffer size : 50000, epsilon : 1.0%
# # of episode :6240, avg score : 91.0, buffer size : 50000, epsilon : 1.0%
# # of episode :6260, avg score : 101.1, buffer size : 50000, epsilon : 1.0%
# # of episode :6280, avg score : 115.4, buffer size : 50000, epsilon : 1.0%
# # of episode :6300, avg score : 81.5, buffer size : 50000, epsilon : 1.0%
# # of episode :6320, avg score : 70.2, buffer size : 50000, epsilon : 1.0%
# # of episode :6340, avg score : 67.3, buffer size : 50000, epsilon : 1.0%
# # of episode :6360, avg score : 83.0, buffer size : 50000, epsilon : 1.0%
# # of episode :6380, avg score : 90.3, buffer size : 50000, epsilon : 1.0%
# # of episode :6400, avg score : 106.0, buffer size : 50000, epsilon : 1.0%
# # of episode :6420, avg score : 114.5, buffer size : 50000, epsilon : 1.0%
# # of episode :6440, avg score : 140.0, buffer size : 50000, epsilon : 1.0%
# # of episode :6460, avg score : 192.2, buffer size : 50000, epsilon : 1.0%
# # of episode :6480, avg score : 98.4, buffer size : 50000, epsilon : 1.0%
# # of episode :6500, avg score : 97.8, buffer size : 50000, epsilon : 1.0%
# # of episode :6520, avg score : 82.8, buffer size : 50000, epsilon : 1.0%
# # of episode :6540, avg score : 89.4, buffer size : 50000, epsilon : 1.0%
# # of episode :6560, avg score : 61.6, buffer size : 50000, epsilon : 1.0%
# # of episode :6580, avg score : 85.8, buffer size : 50000, epsilon : 1.0%
# # of episode :6600, avg score : 80.3, buffer size : 50000, epsilon : 1.0%
# # of episode :6620, avg score : 100.0, buffer size : 50000, epsilon : 1.0%
# # of episode :6640, avg score : 98.6, buffer size : 50000, epsilon : 1.0%
# # of episode :6660, avg score : 82.8, buffer size : 50000, epsilon : 1.0%
# # of episode :6680, avg score : 81.8, buffer size : 50000, epsilon : 1.0%
# # of episode :6700, avg score : 87.8, buffer size : 50000, epsilon : 1.0%
# # of episode :6720, avg score : 63.5, buffer size : 50000, epsilon : 1.0%
# # of episode :6740, avg score : 189.3, buffer size : 50000, epsilon : 1.0%
# # of episode :6760, avg score : 117.9, buffer size : 50000, epsilon : 1.0%
# # of episode :6780, avg score : 122.8, buffer size : 50000, epsilon : 1.0%
# # of episode :6800, avg score : 103.7, buffer size : 50000, epsilon : 1.0%
# # of episode :6820, avg score : 79.4, buffer size : 50000, epsilon : 1.0%
# # of episode :6840, avg score : 69.8, buffer size : 50000, epsilon : 1.0%
# # of episode :6860, avg score : 68.8, buffer size : 50000, epsilon : 1.0%
# # of episode :6880, avg score : 70.9, buffer size : 50000, epsilon : 1.0%
# # of episode :6900, avg score : 71.5, buffer size : 50000, epsilon : 1.0%
# # of episode :6920, avg score : 41.5, buffer size : 50000, epsilon : 1.0%
# # of episode :6940, avg score : 89.5, buffer size : 50000, epsilon : 1.0%
# # of episode :6960, avg score : 75.2, buffer size : 50000, epsilon : 1.0%
# # of episode :6980, avg score : 80.7, buffer size : 50000, epsilon : 1.0%
# # of episode :7000, avg score : 38.7, buffer size : 50000, epsilon : 1.0%
# # of episode :7020, avg score : 51.6, buffer size : 50000, epsilon : 1.0%
# # of episode :7040, avg score : 66.2, buffer size : 50000, epsilon : 1.0%
# # of episode :7060, avg score : 31.4, buffer size : 50000, epsilon : 1.0%
# # of episode :7080, avg score : 65.7, buffer size : 50000, epsilon : 1.0%
# # of episode :7100, avg score : 66.8, buffer size : 50000, epsilon : 1.0%
# # of episode :7120, avg score : 92.8, buffer size : 50000, epsilon : 1.0%
# # of episode :7140, avg score : 86.7, buffer size : 50000, epsilon : 1.0%
# # of episode :7160, avg score : 76.5, buffer size : 50000, epsilon : 1.0%
# # of episode :7180, avg score : 57.6, buffer size : 50000, epsilon : 1.0%
# # of episode :7200, avg score : 93.4, buffer size : 50000, epsilon : 1.0%
# # of episode :7220, avg score : 78.3, buffer size : 50000, epsilon : 1.0%
# # of episode :7240, avg score : 66.8, buffer size : 50000, epsilon : 1.0%
# # of episode :7260, avg score : 96.2, buffer size : 50000, epsilon : 1.0%
# # of episode :7280, avg score : 77.9, buffer size : 50000, epsilon : 1.0%
# # of episode :7300, avg score : 93.6, buffer size : 50000, epsilon : 1.0%
# # of episode :7320, avg score : 97.2, buffer size : 50000, epsilon : 1.0%
# # of episode :7340, avg score : 101.0, buffer size : 50000, epsilon : 1.0%
# # of episode :7360, avg score : 100.5, buffer size : 50000, epsilon : 1.0%
# # of episode :7380, avg score : 93.6, buffer size : 50000, epsilon : 1.0%
# # of episode :7400, avg score : 99.7, buffer size : 50000, epsilon : 1.0%
# # of episode :7420, avg score : 114.4, buffer size : 50000, epsilon : 1.0%
# # of episode :7440, avg score : 106.4, buffer size : 50000, epsilon : 1.0%
# # of episode :7460, avg score : 113.5, buffer size : 50000, epsilon : 1.0%
# # of episode :7480, avg score : 116.6, buffer size : 50000, epsilon : 1.0%
# # of episode :7500, avg score : 109.5, buffer size : 50000, epsilon : 1.0%
# # of episode :7520, avg score : 117.0, buffer size : 50000, epsilon : 1.0%
# # of episode :7540, avg score : 120.8, buffer size : 50000, epsilon : 1.0%
# # of episode :7560, avg score : 123.7, buffer size : 50000, epsilon : 1.0%
# # of episode :7580, avg score : 125.0, buffer size : 50000, epsilon : 1.0%
# # of episode :7600, avg score : 124.8, buffer size : 50000, epsilon : 1.0%
# # of episode :7620, avg score : 145.2, buffer size : 50000, epsilon : 1.0%
# # of episode :7640, avg score : 239.5, buffer size : 50000, epsilon : 1.0%
# # of episode :7660, avg score : 210.7, buffer size : 50000, epsilon : 1.0%
# # of episode :7680, avg score : 382.9, buffer size : 50000, epsilon : 1.0%
# # of episode :7700, avg score : 262.8, buffer size : 50000, epsilon : 1.0%
# # of episode :7720, avg score : 325.7, buffer size : 50000, epsilon : 1.0%
# # of episode :7740, avg score : 285.9, buffer size : 50000, epsilon : 1.0%
# # of episode :7760, avg score : 400.2, buffer size : 50000, epsilon : 1.0%
# # of episode :7780, avg score : 431.6, buffer size : 50000, epsilon : 1.0%
# # of episode :7800, avg score : 385.8, buffer size : 50000, epsilon : 1.0%
# # of episode :7820, avg score : 331.1, buffer size : 50000, epsilon : 1.0%
# # of episode :7840, avg score : 346.6, buffer size : 50000, epsilon : 1.0%
# # of episode :7860, avg score : 282.9, buffer size : 50000, epsilon : 1.0%
# # of episode :7880, avg score : 382.4, buffer size : 50000, epsilon : 1.0%
# # of episode :7900, avg score : 485.6, buffer size : 50000, epsilon : 1.0%
# # of episode :7920, avg score : 484.6, buffer size : 50000, epsilon : 1.0%
# # of episode :7940, avg score : 359.2, buffer size : 50000, epsilon : 1.0%
# # of episode :7960, avg score : 330.7, buffer size : 50000, epsilon : 1.0%
# # of episode :7980, avg score : 335.1, buffer size : 50000, epsilon : 1.0%
# # of episode :8000, avg score : 258.4, buffer size : 50000, epsilon : 1.0%
# # of episode :8020, avg score : 145.4, buffer size : 50000, epsilon : 1.0%
# # of episode :8040, avg score : 304.9, buffer size : 50000, epsilon : 1.0%
# # of episode :8060, avg score : 234.5, buffer size : 50000, epsilon : 1.0%
# # of episode :8080, avg score : 307.8, buffer size : 50000, epsilon : 1.0%
# # of episode :8100, avg score : 412.2, buffer size : 50000, epsilon : 1.0%
# # of episode :8120, avg score : 324.0, buffer size : 50000, epsilon : 1.0%
# # of episode :8140, avg score : 427.4, buffer size : 50000, epsilon : 1.0%
# # of episode :8160, avg score : 472.6, buffer size : 50000, epsilon : 1.0%
# # of episode :8180, avg score : 443.8, buffer size : 50000, epsilon : 1.0%
# # of episode :8200, avg score : 261.7, buffer size : 50000, epsilon : 1.0%
# # of episode :8220, avg score : 428.1, buffer size : 50000, epsilon : 1.0%
# # of episode :8240, avg score : 474.9, buffer size : 50000, epsilon : 1.0%
# # of episode :8260, avg score : 449.9, buffer size : 50000, epsilon : 1.0%
# # of episode :8280, avg score : 396.4, buffer size : 50000, epsilon : 1.0%
# # of episode :8300, avg score : 416.3, buffer size : 50000, epsilon : 1.0%
# # of episode :8320, avg score : 357.0, buffer size : 50000, epsilon : 1.0%
# # of episode :8340, avg score : 402.0, buffer size : 50000, epsilon : 1.0%
# # of episode :8360, avg score : 375.8, buffer size : 50000, epsilon : 1.0%
# # of episode :8380, avg score : 430.6, buffer size : 50000, epsilon : 1.0%
# # of episode :8400, avg score : 385.1, buffer size : 50000, epsilon : 1.0%
# # of episode :8420, avg score : 419.4, buffer size : 50000, epsilon : 1.0%
# # of episode :8440, avg score : 396.2, buffer size : 50000, epsilon : 1.0%
# # of episode :8460, avg score : 461.7, buffer size : 50000, epsilon : 1.0%
# # of episode :8480, avg score : 431.3, buffer size : 50000, epsilon : 1.0%
# # of episode :8500, avg score : 435.4, buffer size : 50000, epsilon : 1.0%
# # of episode :8520, avg score : 465.2, buffer size : 50000, epsilon : 1.0%
# # of episode :8540, avg score : 499.8, buffer size : 50000, epsilon : 1.0%
# # of episode :8560, avg score : 400.0, buffer size : 50000, epsilon : 1.0%
# # of episode :8580, avg score : 487.1, buffer size : 50000, epsilon : 1.0%
# # of episode :8600, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :8620, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :8640, avg score : 456.6, buffer size : 50000, epsilon : 1.0%
# # of episode :8660, avg score : 458.1, buffer size : 50000, epsilon : 1.0%
# # of episode :8680, avg score : 446.5, buffer size : 50000, epsilon : 1.0%
# # of episode :8700, avg score : 485.8, buffer size : 50000, epsilon : 1.0%
# # of episode :8720, avg score : 495.2, buffer size : 50000, epsilon : 1.0%
# # of episode :8740, avg score : 490.0, buffer size : 50000, epsilon : 1.0%
# # of episode :8760, avg score : 483.4, buffer size : 50000, epsilon : 1.0%
# # of episode :8780, avg score : 498.4, buffer size : 50000, epsilon : 1.0%
# # of episode :8800, avg score : 469.8, buffer size : 50000, epsilon : 1.0%
# # of episode :8820, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :8840, avg score : 494.1, buffer size : 50000, epsilon : 1.0%
# # of episode :8860, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :8880, avg score : 494.6, buffer size : 50000, epsilon : 1.0%
# # of episode :8900, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :8920, avg score : 489.2, buffer size : 50000, epsilon : 1.0%
# # of episode :8940, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :8960, avg score : 492.4, buffer size : 50000, epsilon : 1.0%
# # of episode :8980, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9000, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9020, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9040, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9060, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9080, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9100, avg score : 490.4, buffer size : 50000, epsilon : 1.0%
# # of episode :9120, avg score : 468.4, buffer size : 50000, epsilon : 1.0%
# # of episode :9140, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9160, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9180, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9200, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9220, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9240, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9260, avg score : 482.1, buffer size : 50000, epsilon : 1.0%
# # of episode :9280, avg score : 474.1, buffer size : 50000, epsilon : 1.0%
# # of episode :9300, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9320, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9340, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9360, avg score : 476.1, buffer size : 50000, epsilon : 1.0%
# # of episode :9380, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9400, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9420, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9440, avg score : 488.6, buffer size : 50000, epsilon : 1.0%
# # of episode :9460, avg score : 491.2, buffer size : 50000, epsilon : 1.0%
# # of episode :9480, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9500, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9520, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9540, avg score : 471.1, buffer size : 50000, epsilon : 1.0%
# # of episode :9560, avg score : 479.9, buffer size : 50000, epsilon : 1.0%
# # of episode :9580, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9600, avg score : 490.1, buffer size : 50000, epsilon : 1.0%
# # of episode :9620, avg score : 500.0, buffer size : 50000, epsilon : 1.0%
# # of episode :9640, avg score : 493.4, buffer size : 50000, epsilon : 1.0%
# # of episode :9660, avg score : 476.5, buffer size : 50000, epsilon : 1.0%
# # of episode :9680, avg score : 466.2, buffer size : 50000, epsilon : 1.0%
# # of episode :9700, avg score : 301.9, buffer size : 50000, epsilon : 1.0%
# # of episode :9720, avg score : 252.2, buffer size : 50000, epsilon : 1.0%
# # of episode :9740, avg score : 396.2, buffer size : 50000, epsilon : 1.0%
# # of episode :9760, avg score : 468.8, buffer size : 50000, epsilon : 1.0%
# # of episode :9780, avg score : 428.4, buffer size : 50000, epsilon : 1.0%
# # of episode :9800, avg score : 241.8, buffer size : 50000, epsilon : 1.0%
# # of episode :9820, avg score : 463.4, buffer size : 50000, epsilon : 1.0%
# # of episode :9840, avg score : 394.4, buffer size : 50000, epsilon : 1.0%
# # of episode :9860, avg score : 434.1, buffer size : 50000, epsilon : 1.0%
# # of episode :9880, avg score : 473.9, buffer size : 50000, epsilon : 1.0%
# # of episode :9900, avg score : 358.1, buffer size : 50000, epsilon : 1.0%
# # of episode :9920, avg score : 394.6, buffer size : 50000, epsilon : 1.0%
# # of episode :9940, avg score : 271.2, buffer size : 50000, epsilon : 1.0%
# # of episode :9960, avg score : 391.9, buffer size : 50000, epsilon : 1.0%
# # of episode :9980, avg score : 462.6, buffer size : 50000, epsilon : 1.0%
